# %%
    note=float(input("Donnez votre note pour le module R101 :"))
    coéff=int(input("Donnez son coéfficient :"))

# %% [markdown]
# # Calcul des moyennes des UE

# %% [markdown]
# # Algo pour le calcul des moyennes des UE :
# 1°: Demander à l'utilisateur ses notes pour chaque modules des trois UE
# 2°: Demander à l'utilisateur ensuite les coefficients de chaque modules
# 3°: Mettre en place un calcul de ces notes multipliés par chaque coéfficients puis diviser par la somme des coéfficients
# 4°: Si la moyenne sur l'année de chacune des trois UE est ≥10, afficher : "l'année est validée et le passage en BUT 2 est autorisé"
# 5°: Si la moyenne sur l'année de 2 UE est ≥10, alors que la moyenne de la troisième UE est comprise entre 8 (inclus) et 10 (exclu), afficher : "l'année de BUT 1 n'est pas validée mais le passage en BUT 2 est autorisé. Il faudra alors impérativement valider cette dernière UE en BUT 2 (au niveau 2, ce qui validera automatiquement le niveau 1 )"
# 6°: Si la moyenne sur l'année de 2 UE est ≥10, alors que la moyenne de la troisième UE est inférieure à 8 : "l'année n'est pas validée et le passage en BUT 2 n'est pas autorisé. Un redoublement peut-être proposé à l'appréciation du conseil des enseignants."
# 7°: Si la moyenne sur l'année de 2 ou 3 UE est inférieure à 10 : "l'année n'est pas validée et le passage en BUT2 est exclu."

# %%
def calcul_moy():
    sommeR=0
    somme_coeffR=0
    sommeSAE=0
    somme_coeffSAE=0
    for i in range (101,104):
        noteR=float(input("Donnez votre note pour le module R{} pour l'UE1 :".format(i)))
        coeffR=int(input("Donnez le coéfficient pour le module R{} pour l'UE1 :".format(i)))
        sommeR=sommeR+noteR*coeffR
        somme_coeffR=somme_coeffR+coeffR
    moy_R=sommeR/somme_coeffR
    for s in range (11,14):
        noteSAE=float(input("Donnez votre note pour le module SAE{} pour l'UE1 :".format(s)))
        coeffSAE=int(input("Donnez le coéfficient pour le module SAE{} pour l'UE1 :".format(s)))
        sommeSAE=sommeSAE+noteSAE*coeffSAE
        somme_coeffSAE=somme_coeffSAE+coeffSAE
    moy_SAE=sommeSAE/somme_coeffSAE
    moy_1=moy_R+moy_SAE
    print(moy_1)
       
    


    
calcul_moy()
# Out:
# Donnez votre note pour le module R101 pour l'UE1 : 12
# Donnez le coéfficient pour le module R101 pour l'UE1 : 10
# Donnez votre note pour le module R102 pour l'UE1 : 13
# Donnez le coéfficient pour le module R102 pour l'UE1 : 10
# Donnez votre note pour le module R103 pour l'UE1 : 8
# Donnez le coéfficient pour le module R103 pour l'UE1 : 7
# Donnez votre note pour le module SAE11 pour l'UE1 : 14
# Donnez le coéfficient pour le module SAE11 pour l'UE1 : 20
# Donnez votre note pour le module SAE12 pour l'UE1 : 13
# Donnez le coéfficient pour le module SAE12 pour l'UE1 : 20
# Donnez votre note pour le module SAE13 pour l'UE1 : 0
# Donnez le coéfficient pour le module SAE13 pour l'UE1 : 0
# 24.833333333333336

# %%
def calcul_moy():
    sommeR=0
    sommeSAE=0
    somme_coeffT=0
    for i in range (101,104):
        noteR=float(input("Donnez votre note pour le module R{} pour l'UE1 :".format(i)))
        coeffR=int(input("Donnez le coéfficient pour le module R{} pour l'UE1 :".format(i)))
        sommeR=sommeR+noteR*coeffR
    for s in range (11,14):
        noteSAE=float(input("Donnez votre note pour le module SAE{} pour l'UE1 :".format(s)))
        coeffSAE=int(input("Donnez le coéfficient pour le module SAE{} pour l'UE1 :".format(s)))
        sommeSAE=sommeSAE+noteSAE*coeffSAE
    somme_coeffT=coeffR+coeffSAE
    moy_1=sommeSAE+sommeR
    moy_UE1=moy_1/somme_coeffT
    print(moy_UE1)
       
    


    
calcul_moy()
# Out:
# Donnez votre note pour le module R101 pour l'UE1 : 12
# Donnez le coéfficient pour le module R101 pour l'UE1 : 10
# Donnez votre note pour le module R102 pour l'UE1 : 13
# Donnez le coéfficient pour le module R102 pour l'UE1 : 10
# Donnez votre note pour le module R103 pour l'UE1 : 8
# Donnez le coéfficient pour le module R103 pour l'UE1 : 7
# Donnez votre note pour le module SAE11 pour l'UE1 : 16
# Donnez le coéfficient pour le module SAE11 pour l'UE1 : 20
# Donnez votre note pour le module SAE12 pour l'UE1 : 14
# Donnez le coéfficient pour le module SAE12 pour l'UE1 : 20
# Donnez votre note pour le module SAE13 pour l'UE1 : 0
# Donnez le coéfficient pour le module SAE13 pour l'UE1 : 0
# 129.42857142857142
